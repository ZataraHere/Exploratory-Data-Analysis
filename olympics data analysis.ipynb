# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("c:\\Users\\shaba\\PycharmProjects\\Data-Analysis\\Data\\athlete_events.csv")
region_df = pd.read_csv("c:\\Users\\shaba\\PycharmProjects\\Data-Analysis\\Data\\noc_regions.csv")

# %%
df.sample(5)
# Out:
#             ID                    Name Sex   Age  Height  Weight  \
# 221047  111063  Harbinder Singh Chimni   M  21.0   174.0    60.0
# 45066    23243          Aldo Cosentino   M  24.0   162.0    54.0
# 100593   50861     David "Dave" Hughes   M  38.0   185.0    71.0
# 83811    42598        Dnut "Dan" Grecu   M  29.0   170.0    66.0
# 106439   53847           Miroslav Janu   M  28.0   183.0    80.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 221047           India  IND  1964 Summer  1964  Summer           Tokyo
# 45066           France  FRA  1972 Summer  1972  Summer          Munich
# 100593   United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 83811          Romania  ROU  1980 Summer  1980  Summer          Moskva
# 106439  Czech Republic  CZE  2000 Summer  2000  Summer          Sydney
#
#              Sport                                     Event Medal
# 221047      Hockey                       Hockey Men's Hockey  Gold
# 45066       Boxing                 Boxing Men's Bantamweight   NaN
# 100593     Sailing           Sailing Men's Two Person Dinghy   NaN
# 83811   Gymnastics              Gymnastics Men's Horse Vault   NaN
# 106439    Shooting  Shooting Men's Running Target, 10 metres   NaN

# %%
region_df.sample(5)
# Out:
#      NOC       region notes
# 140  MTN   Mauritania   NaN
# 187  SSD  South Sudan   NaN
# 118  LES      Lesotho   NaN
# 146  NEP        Nepal   NaN
# 199  THA     Thailand   NaN

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
region_df.isnull().sum()
# Out:
# NOC         0
# region      3
# notes     209
# dtype: int64

# %%
region_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(1385)

# %%
df.shape
# Out:
# (271116, 15)

# %%
df.drop_duplicates(inplace =True)

# %%
df.shape
# Out:
# (269731, 15)

# %%
df = df[df.Season == 'Summer']

# %%
df.shape
# Out:
# (221167, 15)

# %%
df = pd.merge(df, region_df, on = "NOC", how="outer")

# %%
df['region'].unique()
# Out:
# array(['Afghanistan', 'Curacao', 'Albania', 'Algeria', 'Andorra',
#        'Angola', 'Antigua', 'Australia', 'Argentina', 'Armenia', 'Aruba',
#        'American Samoa', 'Austria', 'Azerbaijan', 'Bahamas', 'Bangladesh',
#        'Barbados', 'Burundi', 'Belgium', 'Benin', 'Bermuda', 'Bhutan',
#        'Bosnia and Herzegovina', 'Belize', 'Belarus', 'Czech Republic',
#        'Boliva', 'Botswana', 'Brazil', 'Bahrain', 'Brunei', 'Bulgaria',
#        'Burkina Faso', 'Central African Republic', 'Cambodia', 'Canada',
#        'Cayman Islands', 'Republic of Congo', 'Chad', 'Chile', 'China',
#        'Ivory Coast', 'Cameroon', 'Democratic Republic of the Congo',
#        'Cook Islands', 'Colombia', 'Comoros', 'Cape Verde', 'Costa Rica',
#        'Croatia', 'Greece', 'Cuba', 'Cyprus', 'Denmark', 'Djibouti',
#        'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'Eritrea',
#        'El Salvador', 'Spain', 'Estonia', 'Ethiopia', 'Russia', 'Fiji',
#        'Finland', 'France', 'Germany', 'Micronesia', 'Gabon', 'Gambia',
#        'UK', 'Guinea-Bissau', 'Georgia', 'Equatorial Guinea', 'Ghana',
#        'Grenada', 'Guatemala', 'Guinea', 'Guam', 'Guyana', 'Haiti',
#        'Honduras', 'Hungary', 'Indonesia', 'India',
#        'Individual Olympic Athletes', 'Iran', 'Ireland', 'Iraq',
#        'Iceland', 'Israel', 'Virgin Islands, US', 'Italy',
#        'Virgin Islands, British', 'Jamaica', 'Jordan', 'Japan',
#        'Kazakhstan', 'Kenya', 'Kyrgyzstan', 'Kiribati', 'South Korea',
#        'Kosovo', 'Saudi Arabia', 'Kuwait', 'Laos', 'Latvia', 'Libya',
#        'Liberia', 'Saint Lucia', 'Lesotho', 'Lebanon', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Madagascar', 'Malaysia', 'Morocco',
#        'Malawi', 'Moldova', 'Maldives', 'Mexico', 'Mongolia',
#        'Marshall Islands', 'Macedonia', 'Mali', 'Malta', 'Montenegro',
#        'Monaco', 'Mozambique', 'Mauritius', 'Mauritania', 'Myanmar',
#        'Namibia', 'Nicaragua', 'Netherlands', 'Nepal', 'Nigeria', 'Niger',
#        'Norway', 'Nauru', 'New Zealand', 'Oman', 'Pakistan', 'Panama',
#        'Paraguay', 'Peru', 'Philippines', 'Palestine', 'Palau',
#        'Papua New Guinea', 'Poland', 'Portugal', 'North Korea',
#        'Puerto Rico', 'Qatar', 'Zimbabwe', nan, 'Romania', 'South Africa',
#        'Rwanda', 'Samoa', 'Serbia', 'Senegal', 'Seychelles', 'Singapore',
#        'Saint Kitts', 'Sierra Leone', 'Slovenia', 'San Marino',
#        'Solomon Islands', 'Somalia', 'Sri Lanka', 'South Sudan',
#        'Sao Tome and Principe', 'Sudan', 'Switzerland', 'Suriname',
#        'Slovakia', 'Sweden', 'Swaziland', 'Syria', 'Tanzania', 'Tonga',
#        'Thailand', 'Tajikistan', 'Turkmenistan', 'Timor-Leste', 'Togo',
#        'Taiwan', 'Trinidad', 'Tunisia', 'Turkey', 'United Arab Emirates',
#        'Uganda', 'Ukraine', 'Uruguay', 'USA', 'Uzbekistan', 'Vanuatu',
#        'Venezuela', 'Vietnam', 'Saint Vincent', 'Yemen', 'Zambia'],
#       dtype=object)

# %%
df['Medal'].value_counts()
# Out:
# Medal
# Gold      11456
# Bronze    11409
# Silver    11212
# Name: count, dtype: int64

# %%
pd.get_dummies(df['Medal'], dtype = int)
# Out:
#         Bronze  Gold  Silver
# 0            0     0       0
# 1            0     0       0
# 2            0     0       0
# 3            0     0       0
# 4            0     0       0
# ...        ...   ...     ...
# 221163       0     0       0
# 221164       0     0       0
# 221165       0     0       0
# 221166       0     0       0
# 221167       0     0       0
#
# [221168 rows x 3 columns]

# %%
df =pd.concat([df, pd.get_dummies(df['Medal'], dtype = int)], axis = 1)

# %%
medal_tally = df.drop_duplicates(subset = ['Team','NOC', 'Games', 'Year', 'City', 'Sport', 'Event' ,'Medal'])

# %%
medal_tally = medal_tally.groupby('NOC').sum()[['Gold','Silver','Bronze']].sort_values('Gold', ascending = False).reset_index()

# %%
medal_tally['Total'] = medal_tally['Gold'] + medal_tally['Silver'] + medal_tally['Bronze']

# %%
medal_tally
# Out:
#      NOC  Gold  Silver  Bronze  Total
# 0    USA  1035     802     708   2545
# 1    URS   394     317     294   1005
# 2    GBR   278     317     300    895
# 3    GER   235     261     283    779
# 4    FRA   234     256     287    777
# ..   ...   ...     ...     ...    ...
# 226  WIF     0       0       2      2
# 227  YEM     0       0       0      0
# 228  YAR     0       0       0      0
# 229  YMD     0       0       0      0
# 230  ZAM     0       1       1      2
#
# [231 rows x 5 columns]

# %%
df.dropna(subset=['Year'], inplace=True)
years = df['Year'].astype('int').unique().tolist()
years.sort()
years.insert(0, 'Overall')

# %%
country = np.unique(df['region'].dropna().values).tolist()
country.sort()
country.insert(0, 'Overall')

# %%
medal_df = df.drop_duplicates(subset = ['Team','NOC', 'Games', 'Year', 'City', 'Sport', 'Event' ,'Medal'])

# %%
medal_df
# Out:
#               ID                           Name Sex   Age  Height  Weight  \
# 0          502.0              Ahmad Shah Abouwi   M   NaN     NaN     NaN
# 1         1076.0          Jammal-ud-Din Affendi   M  28.0     NaN     NaN
# 2         1101.0           Mohammad Anwar Afzal   M   NaN     NaN     NaN
# 3         1745.0                 Mohammad Aktar   M  17.0   156.0    48.0
# 4         4628.0          Mohammad Daoud Anwary   M  22.0     NaN     NaN
# ...          ...                            ...  ..   ...     ...     ...
# 221160  130453.0  Antonette Wilken (-Batchelor)   F  19.0   162.0    49.0
# 221162  130832.0                 Hillary Wilson   F  15.0   157.0    65.0
# 221163  130832.0                 Hillary Wilson   F  15.0   157.0    65.0
# 221165  130880.0            Peter Arthur Wilson   M  20.0   185.0    80.0
# 221166  131478.0          Jennifer "Jenny" Wood   F  16.0   172.0    64.0
#
#                Team  NOC        Games    Year  Season       City      Sport  \
# 0       Afghanistan  AFG  1956 Summer  1956.0  Summer  Melbourne     Hockey
# 1       Afghanistan  AFG  1936 Summer  1936.0  Summer     Berlin     Hockey
# 2       Afghanistan  AFG  1948 Summer  1948.0  Summer     London   Football
# 3       Afghanistan  AFG  1980 Summer  1980.0  Summer     Moskva  Wrestling
# 4       Afghanistan  AFG  1964 Summer  1964.0  Summer      Tokyo  Wrestling
# ...             ...  ...          ...     ...     ...        ...        ...
# 221160     Zimbabwe  ZIM  1980 Summer  1980.0  Summer     Moskva     Diving
# 221162     Zimbabwe  ZIM  1960 Summer  1960.0  Summer       Roma   Swimming
# 221163     Zimbabwe  ZIM  1960 Summer  1960.0  Summer       Roma   Swimming
# 221165     Zimbabwe  ZIM  1980 Summer  1980.0  Summer     Moskva    Sailing
# 221166     Zimbabwe  ZIM  1964 Summer  1964.0  Summer      Tokyo   Swimming
#
#                                              Event Medal       region notes  \
# 0                              Hockey Men's Hockey   NaN  Afghanistan   NaN
# 1                              Hockey Men's Hockey   NaN  Afghanistan   NaN
# 2                          Football Men's Football   NaN  Afghanistan   NaN
# 3       Wrestling Men's Light-Flyweight, Freestyle   NaN  Afghanistan   NaN
# 4          Wrestling Men's Bantamweight, Freestyle   NaN  Afghanistan   NaN
# ...                                            ...   ...          ...   ...
# 221160                     Diving Women's Platform   NaN     Zimbabwe   NaN
# 221162       Swimming Women's 400 metres Freestyle   NaN     Zimbabwe   NaN
# 221163       Swimming Women's 100 metres Butterfly   NaN     Zimbabwe   NaN
# 221165             Sailing Mixed One Person Dinghy   NaN     Zimbabwe   NaN
# 221166       Swimming Women's 100 metres Butterfly   NaN     Zimbabwe   NaN
#
#         Bronze  Gold  Silver
# 0            0     0       0
# 1            0     0       0
# 2            0     0       0
# 3            0     0       0
# 4            0     0       0
# ...        ...   ...     ...
# 221160       0     0       0
# 221162       0     0       0
# 221163       0     0       0
# 221165       0     0       0
# 221166       0     0       0
#
# [105636 rows x 20 columns]

# %%
def fetch_medal_tally(year, country):
    flag = 0
    medal_df['Year']=medal_df['Year'].astype('int')
    if year == 'Overall' and country == 'Overall':
        temp_df = medal_df
    if year != 'Overall' and country == 'Overall':
        temp_df = medal_df[medal_df['Year']== year]
    if year == 'Overall' and country != 'Overall':
        flag = 1
        temp_df = medal_df[medal_df['region']== country]
    if year != 'Overall' and country != 'Overall':
        temp_df = medal_df[(medal_df['Year']== year) & (medal_df['region'] == country)]

    if flag == 1:
        x = temp_df.groupby('Year').sum()[['Gold','Silver','Bronze']].sort_values('Year').reset_index()
    else:
        x = temp_df.groupby('region').sum()[['Gold','Silver','Bronze']].sort_values('Gold', ascending=False).reset_index()
    
    x['Total'] = x['Gold'] + x['Silver'] + x['Bronze']
    print(x)

# %%
fetch_medal_tally('Overall', 'India')
# Out:
#     Year  Gold  Silver  Bronze  Total
# 0   1900     0       2       0      2
# 1   1920     0       0       0      0
# 2   1924     0       0       0      0
# 3   1928     1       0       0      1
# 4   1932     1       0       0      1
# 5   1936     1       0       0      1
# 6   1948     1       0       0      1
# 7   1952     1       0       1      2
# 8   1956     1       0       0      1
# 9   1960     0       1       0      1
# 10  1964     1       0       0      1
# 11  1968     0       0       1      1
# 12  1972     0       0       1      1
# 13  1976     0       0       0      0
# 14  1980     1       0       0      1
# 15  1984     0       0       0      0
# 16  1988     0       0       0      0
# 17  1992     0       0       0      0
# 18  1996     0       0       1      1
# 19  2000     0       0       1      1
# 20  2004     0       1       0      1
# 21  2008     1       0       2      3
# 22  2012     0       2       4      6
# 23  2016     0       1       1      2
# C:\Users\shaba\AppData\Local\Temp\ipykernel_4148\488241192.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   medal_df['Year']=medal_df['Year'].astype('int')

# %%
medal_df
# Out:
#               ID                           Name Sex   Age  Height  Weight  \
# 0          502.0              Ahmad Shah Abouwi   M   NaN     NaN     NaN
# 1         1076.0          Jammal-ud-Din Affendi   M  28.0     NaN     NaN
# 2         1101.0           Mohammad Anwar Afzal   M   NaN     NaN     NaN
# 3         1745.0                 Mohammad Aktar   M  17.0   156.0    48.0
# 4         4628.0          Mohammad Daoud Anwary   M  22.0     NaN     NaN
# ...          ...                            ...  ..   ...     ...     ...
# 221160  130453.0  Antonette Wilken (-Batchelor)   F  19.0   162.0    49.0
# 221162  130832.0                 Hillary Wilson   F  15.0   157.0    65.0
# 221163  130832.0                 Hillary Wilson   F  15.0   157.0    65.0
# 221165  130880.0            Peter Arthur Wilson   M  20.0   185.0    80.0
# 221166  131478.0          Jennifer "Jenny" Wood   F  16.0   172.0    64.0
#
#                Team  NOC        Games    Year  Season       City      Sport  \
# 0       Afghanistan  AFG  1956 Summer  1956.0  Summer  Melbourne     Hockey
# 1       Afghanistan  AFG  1936 Summer  1936.0  Summer     Berlin     Hockey
# 2       Afghanistan  AFG  1948 Summer  1948.0  Summer     London   Football
# 3       Afghanistan  AFG  1980 Summer  1980.0  Summer     Moskva  Wrestling
# 4       Afghanistan  AFG  1964 Summer  1964.0  Summer      Tokyo  Wrestling
# ...             ...  ...          ...     ...     ...        ...        ...
# 221160     Zimbabwe  ZIM  1980 Summer  1980.0  Summer     Moskva     Diving
# 221162     Zimbabwe  ZIM  1960 Summer  1960.0  Summer       Roma   Swimming
# 221163     Zimbabwe  ZIM  1960 Summer  1960.0  Summer       Roma   Swimming
# 221165     Zimbabwe  ZIM  1980 Summer  1980.0  Summer     Moskva    Sailing
# 221166     Zimbabwe  ZIM  1964 Summer  1964.0  Summer      Tokyo   Swimming
#
#                                              Event Medal       region notes  \
# 0                              Hockey Men's Hockey   NaN  Afghanistan   NaN
# 1                              Hockey Men's Hockey   NaN  Afghanistan   NaN
# 2                          Football Men's Football   NaN  Afghanistan   NaN
# 3       Wrestling Men's Light-Flyweight, Freestyle   NaN  Afghanistan   NaN
# 4          Wrestling Men's Bantamweight, Freestyle   NaN  Afghanistan   NaN
# ...                                            ...   ...          ...   ...
# 221160                     Diving Women's Platform   NaN     Zimbabwe   NaN
# 221162       Swimming Women's 400 metres Freestyle   NaN     Zimbabwe   NaN
# 221163       Swimming Women's 100 metres Butterfly   NaN     Zimbabwe   NaN
# 221165             Sailing Mixed One Person Dinghy   NaN     Zimbabwe   NaN
# 221166       Swimming Women's 100 metres Butterfly   NaN     Zimbabwe   NaN
#
#         Bronze  Gold  Silver
# 0            0     0       0
# 1            0     0       0
# 2            0     0       0
# 3            0     0       0
# 4            0     0       0
# ...        ...   ...     ...
# 221160       0     0       0
# 221162       0     0       0
# 221163       0     0       0
# 221165       0     0       0
# 221166       0     0       0
#
# [105636 rows x 20 columns]
