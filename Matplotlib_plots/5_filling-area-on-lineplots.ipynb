# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("c:\\Users\\shaba\\PycharmProjects\\Data-Analysis\\Data\\data2.csv")
data.head()
# Out:
#    Age  All_Devs  Python  JavaScript
# 0   18     17784   20046       16446
# 1   19     16500   17100       16791
# 2   20     18012   20000       18942
# 3   21     20628   24744       21780
# 4   22     25206   30500       25704

# %%
devs_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']
ages= data['Age']

# %%
plt.style.use('fivethirtyeight')

plt.plot(ages, devs_salaries, color = '#444444',linestyle = "--", label = 'All-devs')

plt.plot(ages, py_salaries, label = 'Python')

overall_median = 57287
plt.fill_between(ages, py_salaries, overall_median,
                where=(py_salaries > overall_median),
                 interpolate = True, alpha = 0.25)

plt.fill_between(ages, py_salaries, overall_median,
                where=(py_salaries <= overall_median),
                 interpolate = True,color = 'red',alpha = 0.25)

plt.legend(loc = 'upper left')
plt.title("Median Salary in USD by Age")
plt.xlabel("Age")
plt.ylabel("Salary(USD)")
# Out:
# Text(0, 0.5, 'Salary(USD)')

# %%
plt.style.use('fivethirtyeight')

plt.plot(ages, devs_salaries, color = '#444444',linestyle = "--", label = 'All-devs')

plt.plot(ages, py_salaries, label = 'Python')

overall_median = 57287
plt.fill_between(ages, py_salaries, devs_salaries,
                where=(py_salaries > devs_salaries),
                 interpolate = True, alpha = 0.25, label = 'Above avg.')

plt.fill_between(ages, py_salaries, devs_salaries,
                where=(py_salaries <= devs_salaries),
                 interpolate = True,color = 'red',alpha = 0.25, label = 'Below avg.')

plt.legend(loc = 'upper left')
plt.title("Median Salary in USD by Age")
plt.xlabel("Age")
plt.ylabel("Salary(USD)")
# Out:
# Text(0, 0.5, 'Salary(USD)')
