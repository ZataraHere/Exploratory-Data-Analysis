# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mpl_dates
from datetime import datetime

# %%
plt.style.use('seaborn-v0_8')

dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

plt.plot(dates,y, linestyle = '-', marker = 'o')

plt.gcf().autofmt_xdate()

date_format = mpl_dates.DateFormatter('%d %b, 20%y')
plt.gca().xaxis.set_major_formatter(date_format)

# %%
# Bitcoin Data
data = pd.read_csv("c:\\Users\\shaba\\PycharmProjects\\Data-Analysis\\Data\\data4.csv")
data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-05-18  7266.080078  8281.660156  7257.259766  8193.139648
# 1  2019-05-19  8193.139648  8193.139648  7591.850098  7998.290039
# 2  2019-05-20  7998.290039  8102.319824  7807.770020  7947.930176
# 3  2019-05-21  7947.930176  8033.759766  7533.660156  7626.890137
# 4  2019-05-22  7626.890137  7971.259766  7478.740234  7876.500000
#
#      Adj Close     Volume
# 0  8193.139648  723011166
# 1  7998.290039  637617163
# 2  7947.930176  357803946
# 3  7626.890137  424501866
# 4  7876.500000  386766321

# %%
price_date = data['Date']
price_close = data['Close']

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace = True)

plt.plot(price_date, price_close, linestyle = '-', marker = 'o')

plt.gcf().autofmt_xdate()
